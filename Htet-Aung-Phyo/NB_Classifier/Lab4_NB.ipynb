# %%
import pandas as pd

df=pd.read_csv('D:/Tyler_Data/Other Skills/Datascience/MMDT_GitHub/MMDT_2025_MLAI101/Htet-Aung-Phyo/NB_Classifier/fraud.csv', index_col = 0)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score

# %%
df.head(5)
# Out:
#    Unnamed: 0        V1        V2        V3        V4        V5        V6  \
# 0           0  1.176563  0.323798  0.536927  1.047002 -0.368652 -0.728586
# 1           1  0.681109 -3.934776 -3.801827 -1.147468 -0.735540 -0.501097
# 2           2  1.140729  0.453484  0.247010  2.383132  0.343287  0.432804
# 3           3 -1.107073 -3.298902 -0.184092 -1.795744  2.137564 -1.684992
# 4           4 -0.314818  0.866839 -0.124577 -0.627638  2.651762  3.428128
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.084678 -0.069246 -0.266389  ... -0.109627 -0.341365  0.057845  0.499180
# 1  1.038865 -0.626979 -2.274423  ...  0.652202  0.272684 -0.982151  0.165900
# 2  0.093380  0.173310 -0.808999  ... -0.003802  0.058556 -0.121177 -0.304215
# 3 -2.015606 -0.007181 -0.165760  ...  0.130648  0.329445  0.927656 -0.049560
# 4  0.194637  0.670674 -0.442658  ... -0.312774 -0.799494 -0.064488  0.953062
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
y = df['Class'].values
df = df.iloc[:,1:]
X = df.drop(columns = 'Class').values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                    test_size = 0.40, 
                                    random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
ypred_test = gnb.predict(X_test)
gnb_mat = confusion_matrix(y_test, ypred_test)
gnb_report = classification_report(y_test, ypred_test)

print(gnb_mat)
print(gnb_report)


auc = roc_auc_score(y_test, ypred_test)
print(auc)
# Out:
# [[8349  192]
#  [  19  118]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      8541
#            1       0.38      0.86      0.53       137
#
#     accuracy                           0.98      8678
#    macro avg       0.69      0.92      0.76      8678
# weighted avg       0.99      0.98      0.98      8678
#
# 0.919417032655709

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()  # scale features to [0,1]
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB(alpha=1.0)
mnb.fit(X_train_scaled, y_train)
# Out:
# MultinomialNB()

# %%
ypred_test = mnb.predict(X_test_scaled)
mnb_mat = confusion_matrix(y_test, ypred_test)
mnb_report = classification_report(y_test, ypred_test)

print(mnb_mat)
print(mnb_report)


auc = roc_auc_score(y_test, ypred_test)
print(auc)
# Out:
# [[8541    0]
#  [ 137    0]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8541
#            1       0.00      0.00      0.00       137
#
#     accuracy                           0.98      8678
#    macro avg       0.49      0.50      0.50      8678
# weighted avg       0.97      0.98      0.98      8678
#
# 0.5
# c:\Users\Htet\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Htet\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.naive_bayes import BernoulliNB
bnb = BernoulliNB(alpha=1.0)
bnb.fit(X_train, y_train)
# Out:
# BernoulliNB()

# %%
ypred_test = bnb.predict(X_test)
bnb_mat = confusion_matrix(y_test, ypred_test)
bnb_report = classification_report(y_test, ypred_test)

print(bnb_mat)
print(bnb_report)


auc = roc_auc_score(y_test, ypred_test)
print(auc)
# Out:
# [[8533    8]
#  [  33  104]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8541
#            1       0.93      0.76      0.84       137
#
#     accuracy                           1.00      8678
#    macro avg       0.96      0.88      0.92      8678
# weighted avg       1.00      1.00      1.00      8678
#
# 0.8790937145601679
